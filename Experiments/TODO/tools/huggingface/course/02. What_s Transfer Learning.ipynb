# %% [markdown]
# ## Transfern Learning
# <br>
#
# Transfern Learing é quando um modelo A passa conhecimento para um modelo B.
#
# <br>
#
# **Referências desta aula**
#
# - [ImageNet](https://www.image-net.org/)
