# %% [markdown]
# ## Accelerate your Pytorch training
# <br>
#
# - [Aula](https://www.youtube.com/watch?v=s7dy8QRgjJ0&list=PLo2EIpI_JMQvWfQndUesu0nPBAtZ9gP1o&index=31)
#
# - [Accelerate on HF](https://huggingface.co/docs/accelerate/index)
#
# Accelerate auxilia na etapa de treinamento e validação dos seu modelo.
