# %% [markdown]
# ## Decoders
# Decoders são diferentes dos Encoders porque olham apenas para uma direção (left), em algo chamado masked self-attention.
#
# Decoders são bem em criar novas coisas (generating).
# <br>
#
# Exemplo de Decoder:
#
# - GPT-2
# - GPT Neo
