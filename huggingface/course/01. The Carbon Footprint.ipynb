# %% [markdown]
# ## The Carbon Footprint of Transformers
#
# <br>
#
# **Considerações em prol de modelos pré-treinados**
#
# - Não é necessário ter o trabalho de treinar
#
# - Se precisar de ajustes basta aplicar Fine-tuning
#
# <br>
#
# **Referências dessa aula**
# - [Code Carbon](https://codecarbon.io/)

# %%
# Drive
from google.colab import drive
drive.mount('/content/drive')
