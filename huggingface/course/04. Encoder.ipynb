# %% [markdown]
# ## Encoder
# <br>
#
# Encoder são capazes de transformar letras em número, digamos.
#
# **"Bem-vindo a NYT" pode se transformar em..**
#
# - 0.1, 0.2
# - 0.3,0.1
# - 0.2,0.3
#
# Esse resultado é chamado de feature vector ou feature tensor.
#
# <br>
#
# Exemplo de Decoders
# - BERT
# - RoBERTa
# - ALBERT

# %%
from google.colab import drive
drive.mount('/content/drive')
