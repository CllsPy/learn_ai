# %% [markdown]
# # What's dynamic padding
# <br>
#
# - [Aula](https://www.youtube.com/watch?v=7q5NyFT8REg&list=PLo2EIpI_JMQvWfQndUesu0nPBAtZ9gP1o&index=24)
# <br>
#
# Padding é complementar a palavra com elementos especiais para que ela tenha o mesmo tamanho da maior palavra possível, dynamic padding é quando isso é feito de forma automática.
