# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Tokenizer
# <br>
#
# Tokenizar é transformar uma palavra em um número, de modo que o modelo seja capaz de ler/compreender, três métodos são:
#
# - Word-Based
# - Character-Based
# - Subword-Base
