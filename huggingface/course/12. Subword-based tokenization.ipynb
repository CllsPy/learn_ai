# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Subword-base
# <br>
#
# É um meio termo entre os dois tipos vistos anteriormente.
#
# 1. Palavras que aparecem muitas vezes não são divididas como na Word-base.
#
# 2. Caracteres que aparecem pouco devem ser dividodos como nas Character-base.
