# %% [markdown]
# # How batch inputs together
# <br>
#
# -  [Aula](https://www.youtube.com/watch?v=M6adb1j2jPI&list=PLo2EIpI_JMQvWfQndUesu0nPBAtZ9gP1o&index=18)

# %% [markdown]
# São instruções de como processar setença com tamanho diferente adicionando caracteres especiaisa para que possamos transformar em tensor a saída.
