# %% [markdown]
# ## Loading a Custom Dataset
# <br>
#
# - [Aula](https://www.youtube.com/watch?v=HyQgpJTkRdE&list=PLo2EIpI_JMQvWfQndUesu0nPBAtZ9gP1o&index=36)
#
# - [UCI - Datasets](https://archive.ics.uci.edu/datasets)

# %%
# %%capture
# !pip install datasets

# %%
from datasets import load_dataset

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Dados/ZTMMLCOURSE/assets/data/51 - car-sales.csv"
load_csv = load_dataset(
    "csv",
    data_files=path,
    sep=";"
    )

load_csv
