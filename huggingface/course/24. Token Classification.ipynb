# %% [markdown]
# ## Token Classification
# <br>
#
# - [Aula](https://www.youtube.com/watch?v=0E7ltQB7fM8&list=PLo2EIpI_JMQvWfQndUesu0nPBAtZ9gP1o&index=46)
#
# - HuggingFace
#   - Token Classification
#   - Distilbert

# %%
from transformers import pipeline

# %%
# %%capture
token_classifier = pipeline("token-classification")

# %%
token_classifier("Hey, my name is Carlos I work at Google!")[1]
