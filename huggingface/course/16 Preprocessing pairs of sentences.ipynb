# %% [markdown]
# # Preprocessing pairs of sentences
# <br>
#
# - [Aula](https://www.youtube.com/watch?v=0u3ioSwev3s&list=PLo2EIpI_JMQvWfQndUesu0nPBAtZ9gP1o&index=22)
# <br>
#
# A aula sobre sobre como tokenizar duas setenças ao mesmo tempo o que pode ser útil em tarefas que precisam de comperação entre elas.
